# %% [markdown]
# # LightBox API - Purpose of Adjacent Parcels
#
# Query for adjacent parcels to the parcel noted by the parcel LightBox 'ID.' Alternately pass in commonOwnership=true and get only the parcels adjacent to this parcel that have common ownership.

# %% [markdown]
# ## Finding Adjacent Parcels with Common Ownership
#
# This notebook demonstrates basic features of the LightBox Parcels API by walking through the following steps:
#
# 1. **Setup**
#    - Importing necessary Python libraries.
#    - Defining global configurations and API keys.
#
# 2. **Function Definition(s)**
#    - `get_common_owners`: Function to take a LightBox ID and Country Code, and a Common Ownership flag to determine adjacent parcels with a common owner.
#
# 3. **API Key**
#    - Enter your API Key for Authorization.
#
# 4. **Create request objects and display the results in JSON form.**
#    - User will input the LightBoxID and/or Country Code, and set the commonOwnership flag to true to retrieve adjacent parcel(s) with common ownership.
#    - The API call will be made and the response will be printed.

# %% [markdown]
# ### 1. Import the required python packages

# %%
import requests
import json
from typing import Dict

# %% [markdown]
# ### 2. Import function definitions

# %%
# ----------------------------
# Function Definitions
# ----------------------------
def get_common_owners(lightbox_api_key: str, country_code: str, id: str, common_ownership: str) -> Dict:
    """
    Query for adjacent parcel(s) with a common owner using the LightBox parcel 'ID.'
    
    Args:
        lightbox_api_key (str): The API key for accessing the LightBox API.
        id (str): The LightBox ID for the specified parcel.
        country_code (str): ISO 3166 alpha-2 country code (e.g., 'us' for the United States). 
        common_ownership (boolean): Flag to return only parcels that have a common ownership with the target parcel ID. If false return parcels that intersect the parcel noted by the parcel LightBox ID.
    Returns:
        dict: The parcel information in JSON format.
    """
    # API endpoint configuration
    BASE_URL = "https://api.lightboxre.com/v1"
    ENDPOINT = f"/parcels/_adjacent/{country_code}/{id}?commonOwnership='{common_ownership}'" # Concatenate endpoint with country code, id and common ownership value
    URL = BASE_URL + ENDPOINT

    # Setting up request parameters and headers
    headers = {'x-api-key': lightbox_api_key}

    # Sending request to the LightBox API
    response = requests.get(URL, headers=headers)
    return response

# %% [markdown]
# ### 3. Create variables that will be used to authenticate your calls.
# Get your key from the [LightBox Developer Portal](https://developer.lightboxre.com/).

# %%
lightbox_api_key = '<YOUR_API_KEY>'

# %% [markdown]
# ### 4. Querying the Parcels API

# %%
# Specify the LightBoxID
id = '0201MABNPDBU5D2EGP08YA'

# Specify the Country Code
country_code = "us"

# Pass in common_ownership=true and get only the parcels adjacent to this parcel that have common ownership.
common_ownership = "true"

# Get the parcel data for the specified LightBoxID
data = get_common_owners(lightbox_api_key, country_code, id, common_ownership)

# Print the common ownership data in a readable JSON format
print(json.dumps(data.json(), indent=4))
# Out:
# {
#     "$ref": "https://api.lightboxre.com/v1/parcels/_adjacent/us/0201MABNPDBU5D2EGP08YA?commonOwnership=%27true%27",
#     "$metadata": {
#         "geogcs": {
#             "epsg": "4269"
#         },
#         "currency": {
#             "code": "usd"
#         },
#         "units": {
#             "length": "m",
#             "area": "sqm"
#         },
#         "recordSet": {
#             "totalRecords": 2.0,
#             "offset": null,
#             "limit": null,
#             "bbox": {
#                 "xMax": -89.317251,
#                 "xMin": -89.335063,
#                 "yMax": 34.917256,
#                 "yMin": 34.902708
#             }
#         }
#     },
#     "parcels": [
#         {
#             "$ref": "https://api.lightboxre.com/v1/parcels/us/0201G0JK89DFVN47IDDQL2",
#             "id": "0201G0JK89DFVN47IDDQL2",
#             "$metadata": {
#                 "geocode": null
#             },
#             "fips": "28009",
#             "parcelApn": "2-0091-17-000-006.00",
#             "assessment": {
#                 "alternateApn": "13959",
#                 "apn": "2-0091-17-000-006.00",
#                 "assessedValue": {
#                     "total": 6008.0,
#                     "land": null,
#                     "improvements": null,
#                     "year": "2023"
#                 },
#                 "marketValue": {
#                     "total": 60080.0,
#                     "land": 2500.0,
#                     "improvements": 57580.0,
#                     "year": "2023"
#                 },
#                 "improvementPercent": null,
#                 "lot": {
#                     "lotNumber": "80,81",
#                     "blockNumber": null,
#                     "depth": null,
#                     "width": null,
#                     "size": 4048.3271375464683
#                 },
#                 "poolIndicator": null,
#                 "zoning": {
#                     "assessment": null
#                 },
#                 "book": null,
#                 "page": null
#             },
#             "cbsa": {
#                 "code": null
#             },
#             "census": {
#                 "blockGroup": "1",
#                 "tract": "950101"
#             },
#             "county": "BENTON",
#             "derived": {
#                 "calculatedLotArea": 3923.6059479553905
#             },
#             "landUse": {
#                 "code": "001",
#                 "description": "RESIDENCE",
#                 "normalized": {
#                     "code": "1001",
#                     "description": "SINGLE FAMILY RESIDENTIAL",
#                     "categoryDescription": "RESIDENTIAL"
#                 }
#             },
#             "lastLoan": {
#                 "recordingDate": "2020-06-29T00:00:00.000Z",
#                 "dueDate": "2025-06-15T00:00:00.000Z",
#                 "lender": "BANK OF HOLLY SPRINGS",
#                 "value": 22585.0,
#                 "transactionId": "",
#                 "interestRates": []
#             },
#             "legalDescription": [
#                 "LOT 80 & 81 LOT 10 W 1/2 LOT 19 DB 62-90 SITE VALUE 146/500"
#             ],
#             "location": {
#                 "streetAddress": "66 LEAK DR",
#                 "countryCode": "US",
#                 "locality": "LAMAR",
#                 "regionCode": "MS",
#                 "postalCode": "38642",
#                 "postalCodeExt": null,
#                 "geometry": {
#                     "wkt": "POLYGON ((-89.3173798698092 34.9139892928925, -89.3173827518834 34.9142418657049, -89.317916940478 34.9144855497049, -89.3179079754372 34.9147327173138, -89.3181997701329 34.9148658252548, -89.3183484356357 34.9146446963056, -89.3187336054724 34.9148203970798, -89.318764307927 34.9147747290358, -89.3185162816413 34.9146615885968, -89.3185954616081 34.9145438131211, -89.3173798698092 34.9139892928925))"
#                 },
#                 "representativePoint": {
#                     "longitude": -89.318007,
#                     "latitude": 34.914456,
#                     "geometry": {
#                         "wkt": "POINT (-89.318007 34.914456)"
#                     }
#                 }
#             },
#             "neighborhood": null,
#             "occupant": {
#                 "owner": false,
#                 "company": false
#             },
#             "owner": {
#                 "names": [
#                     {
#                         "fullName": "MILLER, HAZEL LAVERNE",
#                         "firstName": "HAZEL",
#                         "middleName": "LAVERNE",
#                         "lastName": "MILLER"
#                     }
#                 ],
#                 "streetAddress": "2329 HIGHWAY 7",
#                 "countryCode": "US",
#                 "locality": "LAMAR",
#                 "regionCode": "MS",
#                 "postalCode": "38642",
#                 "postalCodeExt": null,
#                 "ownerNameStd": null,
#                 "ownershipStatus": {
#                     "code": "GV",
#                     "description": "GOVERNMENT"
#                 }
#             },
#             "opportunityZone": false,
#             "primaryStructure": {
#                 "yearBuilt": "1942",
#                 "yearRenovated": null
#             },
#             "related": {
#                 "commonOwnership": {
#                     "aggregateLotSize": 4046.86,
#                     "id": "100660192_52957893",
#                     "count": 1.0,
#                     "subdivision": null,
#                     "lotWidthMedian": null,
#                     "lotWidthSummary": null
#                 },
#                 "associatePropertyCount": 1.0
#             },
#             "subdivision": null,
#             "structures": [
#                 {
#                     "$ref": "https://api.lightboxre.com/v1/structures/0506EWEHHQYCUQGFEKXMJX",
#                     "id": "0506EWEHHQYCUQGFEKXMJX"
#                 }
#             ],
#             "tax": {
#                 "year": null,
#                 "yearDelinquent": null,
#                 "amount": null,
#                 "taxRateAreaCode": null,
#                 "id": "US_28_009_2-0091-17-000-006.00",
#                 "taxAccountNumber": "13959",
#                 "exemption": "SENIOR CITIZEN"
#             },
#             "topography": "",
#             "transaction": {
#                 "lastMarketSale": {
#                     "pricePerArea": null,
#                     "value": null,
#                     "seller": "",
#                     "buyer": "MILLER HAZEL",
#                     "filingDate": "2012-11-16T00:00:00.000Z",
#                     "transferDate": "2012-11-16T00:00:00.000Z",
#                     "documentNumber": "",
#                     "documentTypeCode": "",
#                     "documentTypeDescription": "",
#                     "lender": "",
#                     "loan": {
#                         "code": "",
#                         "description": "",
#                         "first": null,
#                         "second": null
#                     },
#                     "sale": {
#                         "code": null,
#                         "description": null
#                     },
#                     "titleCompany": null,
#                     "tdDocumentNumber": null,
#                     "deedTransactionType": null,
#                     "lenderType": null
#                 },
#                 "priorMarketSale": {
#                     "transferDate": null,
#                     "lender": ""
#                 },
#                 "multipleApnFlag": ""
#             },
#             "usplss": {
#                 "township": "002",
#                 "range": "001",
#                 "section": "17",
#                 "quarter": null
#             }
#         },
#         {
#             "$ref": "https://api.lightboxre.com/v1/parcels/us/02059ND3VCTQIU742MGC88",
#             "id": "02059ND3VCTQIU742MGC88",
#             "$metadata": {
#                 "geocode": null
#             },
#             "fips": "28009",
#             "parcelApn": "STREET_16408",
#             "assessment": {
#                 "alternateApn": null,
#                 "apn": "STREET_16408",
#                 "assessedValue": {
#                     "total": null,
#                     "land": null,
#                     "improvements": null,
#                     "year": null
#                 },
#                 "marketValue": {
#                     "total": null,
#                     "land": null,
#                     "improvements": null,
#                     "year": null
#                 },
#                 "improvementPercent": null,
#                 "lot": {
#                     "lotNumber": null,
#                     "blockNumber": null,
#                     "depth": null,
#                     "width": null,
#                     "size": null
#                 },
#                 "poolIndicator": null,
#                 "zoning": {
#                     "assessment": null
#                 },
#                 "book": null,
#                 "page": null
#             },
#             "cbsa": {
#                 "code": null
#             },
#             "census": {
#                 "blockGroup": null,
#                 "tract": null
#             },
#             "county": null,
#             "derived": {
#                 "calculatedLotArea": 102755.48327137547
#             },
#             "landUse": {
#                 "code": null,
#                 "description": null,
#                 "normalized": {
#                     "code": null,
#                     "description": null,
851197 34.9151857411482, -89.3182940729541 34.9154741703724, -89.3183290886252 34.915490143307, -89.3185230008713 34.9152017140278, -89.3187272589103 34.9152948885226, -89.3177692647572 34.9167198127638, -89.3177028030426 34.9170360098178, -89.3176508409428 34.9170576615143, -89.3175813711444 34.9170847331484, -89.317415899715 34.9171466145836, -89.3174171431617 34.9172555671305, -89.3228760096701 34.9172398844971, -89.3231718559436 34.9169132288713, -89.3241752615443 34.9158388222164, -89.3252953421787 34.914695299426, -89.3258630705572 34.9141398188941, -89.3266165008008 34.9134144827168, -89.3273129537145 34.9127584430809, -89.3280555738271 34.9120950381616, -89.3294091725147 34.9109215486468, -89.3300483467371 34.9103915020247, -89.3307807814133 34.9097901203926, -89.3319913718409 34.9088441629077, -89.332157511655 34.9087124869807, -89.332301141979 34.9086002701403, -89.3324862144233 34.9084578422923, -89.3326393702314 34.9083417874205, -89.3329522538788 34.9081096469205, -89.3338957780353 34.9074215708291, -89.3344721617005 34.9070059500719, -89.3347265357356 34.9068246971932, -89.3350627768445 34.9065869939673, -89.33505476935 34.906230 ...
#                 },
#                 "representativePoint": {
#                     "longitude": -89.319841,
#                     "latitude": 34.917234,
#                     "geometry": {
#                         "wkt": "POINT (-89.319841 34.917234)"
#                     }
#                 }
#             },
#             "neighborhood": null,
#             "occupant": {},
#             "owner": {
#                 "names": null,
#                 "streetAddress": null,
#                 "countryCode": "US",
#                 "locality": null,
#                 "regionCode": null,
#                 "postalCode": null,
#                 "postalCodeExt": null,
#                 "ownerNameStd": null,
#                 "ownershipStatus": {
#                     "code": null,
#                     "description": null
#                 }
#             },
#             "opportunityZone": false,
#             "primaryStructure": {
#                 "yearBuilt": null,
#                 "yearRenovated": null
#             },
#             "related": {
#                 "commonOwnership": {
#                     "aggregateLotSize": 101171.5,
#                     "id": "553910051_370",
#                     "count": 1.0,
#                     "subdivision": null,
#                     "lotWidthMedian": null,
#                     "lotWidthSummary": null
#                 },
#                 "associatePropertyCount": null
#             },
#             "subdivision": null,
#             "structures": [],
#             "tax": {
#                 "year": null,
#                 "yearDelinquent": null,
#                 "amount": null,
#                 "taxRateAreaCode": "",
#                 "id": null,
#                 "taxAccountNumber": null,
#                 "exemption": null
#             },
#             "topography": "",
#             "transaction": {
#                 "lastMarketSale": {
#                     "pricePerArea": null,
#                     "value": null,
#                     "seller": "",
#                     "buyer": "",
#                     "filingDate": null,
#                     "transferDate": null,
#                     "documentNumber": "",
#                     "documentTypeCode": "",
#                     "documentTypeDescription": "",
#                     "lender": "",
#                     "loan": {
#                         "code": "",
#                         "description": "",
#                         "first": null,
#                         "second": null
#                     },
#                     "sale": {
#                         "code": null,
#                         "description": null
#                     },
#                     "titleCompany": null,
#                     "tdDocumentNumber": null,
#                     "deedTransactionType": null,
#                     "lenderType": null
#                 },
#                 "priorMarketSale": {
#                     "transferDate": null,
#                     "lender": ""
#                 },
#                 "multipleApnFlag": ""
#             },
#             "usplss": {
#                 "township": null,
#                 "range": null,
#                 "section": null,
#                 "quarter": null
#             }
#         }
#     ]
# }
