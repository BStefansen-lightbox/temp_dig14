# %% [markdown]
# # LightBox API - Using LightBox ID as an Input
#
# This notebook is designed to demonstrate the capability of the LightBox API to fetch a wide array of data sets using a single, unique identifier: the LightBoxID. By providing a LightBoxID, users can access detailed information across multiple endpoints including demographics, flood hazards, risk indexes, wetlands, and zoning information. This approach showcases the integration of diverse data points that are essential for comprehensive analysis in fields such as real estate, environmental planning,...
#
# **Objective**: To provide a practical demonstration on how to use the LightBoxID to access and integrate various datasets for analysis and decision-making.
#
# ### 1. Setup
# - Importing necessary Python libraries.
#
# ### 2. Function Definitions
# - Definitions of functions to access data from multiple API endpoints using LightBoxID.
# - Endpoints Covered:
#     - `Parcel Details`: Access nationwide parcel boundaries with a large selection of property and tax attributes to help you make more confident decisions. Covers 3,100+ U.S. counties including territories, with over 150 million parcels with polygon geometry that is normalized across state and county boundaries.
#     - `Demographics`: Demographic analysis examines and measures the dimensions and dynamics of populations. The LightBox Demographic API unit of measure is at the Census Block Group. Using this API will give one insights into population dimensions.
#     - `National Flood Hazard Layers (NFHL)`: The National Flood Hazard Layer (NFHL) is a geospatial database that contains current effective flood hazard data. FEMA provides the flood hazard data to support the National Flood Insurance Program. You can use the information to better understand your level of flood risk and type of flooding.
#     - `National Risk Indexes`: The National Risk Index is easy to use and can be leveraged to support decisions regarding disaster response, recovery, and mitigation. It helps in understanding and assessing the risk of natural hazards in various regions.
#     - `Wetlands`: The Wetlands mapping API provides detailed information about wetland type and extent for ecological and environmental planning purposes.
#     - `Zoning`: Access zoning information to understand local laws and regulations that may affect property development and use. It is crucial for compliance and planning in real estate developments.
#
# ### 3. API Key
# - Prompt for entering your API Key to authorize requests.
#
# ### 4. Fetching Data
# - Making API calls using the LightBoxID and/or Country Code to retrieve data from the specified endpoints.
# - Displaying the results in JSON format for each dataset.

# %% [markdown]
# ### 1. Import the required python packages

# %%
import requests
import json
from typing import Dict

# %% [markdown]
# ### 2. Import function definitions
#
# **Function Definitions**
#    - `get_parcel`: Function to query for a specific parcel using the LightBox parcel 'ID'.
#    - `get_demographics`: Function to query for demographic record identified by a LightBox Parcel 'ID'.
#    - `get_wetlands`: Function to query for wetland records related to a parcel by the LightBox parcel 'ID'.
#    - `get_nfhls`: Function to query for a specific national flood hazard records using the LightBox Parcel 'ID'.
#    - `get_risk_indexes`: Function to query for a specific national risk index records using the LightBox Parcel 'ID'.
#    - `get_zoning`: Function to query for zoning records related to a parcel by the LightBox parcel 'ID'.

# %%
def get_parcel(lightbox_api_key: str, countryCode: str, id: str) -> Dict:
    """
    Query for a specific parcel using the LightBox parcel 'ID.'
    
    Args:
        lightbox_api_key (str): The API key for accessing the LightBox API.
        id (str): The LightBox ID for the specified parcel.
        countryCode (str): ISO 3166 alpha-2 country code (e.g., 'US' for the United States). 
    
    Returns:
        dict: The parcel information in JSON format.
    """
    # API endpoint configuration
    BASE_URL = "https://api.lightboxre.com/v1"
    ENDPOINT = f"/parcels/{countryCode}/{id}" # Concatenate endpoint with country code and id
    URL = BASE_URL + ENDPOINT

    # Setting up request parameters and headers
    headers = {'x-api-key': lightbox_api_key}

    # Sending request to the LightBox API
    response = requests.get(URL, headers=headers)
    return response

def get_demographics(lightbox_api_key: str, id: str) -> Dict:
    """
    Query for demographic record identified by a LightBox Parcel 'ID.'
    
    Args:
        lightbox_api_key (str): The API key for accessing the LightBox API.
        id (str): The LightBox ID for the specified parcel.
    
    Returns:
        dict: The parcel information in JSON format.
    """
    # API endpoint configuration
    BASE_URL = "https://api.lightboxre.com/v1"
    ENDPOINT = f"/demographics/_on/parcel/us/{id}" # Concatenate endpoint with the id
    URL = BASE_URL + ENDPOINT

    # Setting up request parameters and headers
    headers = {'x-api-key': lightbox_api_key}

    # Sending request to the LightBox API
    response = requests.get(URL, headers=headers)
    return response

def get_wetlands(lightbox_api_key: str, id: str) -> Dict:
    """
    Query for wetland records related to a parcel by the LightBox parcel 'ID.'
    
    Args:
        lightbox_api_key (str): The API key for accessing the LightBox API.
        id (str): The LightBox ID for the specified parcel.
    
    Returns:
        dict: The parcel information in JSON format.
    """
    # API endpoint configuration
    BASE_URL = "https://api.lightboxre.com/v1"
    ENDPOINT = f"/wetlands/_on/parcel/us/{id}" # Concatenate endpoint with the id
    URL = BASE_URL + ENDPOINT

    # Setting up request parameters and headers
    headers = {'x-api-key': lightbox_api_key}

    # Sending request to the LightBox API
    response = requests.get(URL, headers=headers)
    return response

def get_nfhls(lightbox_api_key: str, id: str) -> Dict:
    """
    Query for a specific national flood hazard records using the LightBox Parcel 'ID.'
    
    Args:
        lightbox_api_key (str): The API key for accessing the LightBox API.
        id (str): The LightBox ID for the specified parcel.
    
    Returns:
        dict: The parcel information in JSON format.
    """
    # API endpoint configuration
    BASE_URL = "https://api.lightboxre.com/v1"
    ENDPOINT = f"/nfhls/_on/parcel/us/{id}" # Concatenate endpoint with the id
    URL = BASE_URL + ENDPOINT

    # Setting up request parameters and headers
    headers = {'x-api-key': lightbox_api_key}

    # Sending request to the LightBox API
    response = requests.get(URL, headers=headers)
    return response

def get_risk_indexes(lightbox_api_key: str, id: str) -> Dict:
    """
    Query for a specific national risk index records using the LightBox Parcel 'ID.'
    
    Args:
        lightbox_api_key (str): The API key for accessing the LightBox API.
        id (str): The LightBox ID for the specified parcel.
    
    Returns:
        dict: The parcel information in JSON format.
    """
    # API endpoint configuration
    BASE_URL = "https://api.lightboxre.com/v1"
    ENDPOINT = f"/riskindexes/_on/parcel/us/{id}" # Concatenate endpoint with the id
    URL = BASE_URL + ENDPOINT

    # Setting up request parameters and headers
    headers = {'x-api-key': lightbox_api_key}

    # Sending request to the LightBox API
    response = requests.get(URL, headers=headers)
    return response

def get_zoning(lightbox_api_key: str, countryCode: str, id: str) -> Dict:
    """
    Query for zoning records related to a parcel by the LightBox parcel 'ID.'
    
    Args:
        lightbox_api_key (str): The API key for accessing the LightBox API.
        id (str): The LightBox ID for the specified parcel.
        countryCode (str): ISO 3166 alpha-2 country code (e.g., 'US' for the United States). 
    
    Returns:
        dict: The parcel information in JSON format.
    """
    # API endpoint configuration
    BASE_URL = "https://api.lightboxre.com/v1"
    ENDPOINT = f"/zoning/_on/parcel/{countryCode}/{id}" # Concatenate endpoint with the country code and id
    URL = BASE_URL + ENDPOINT

    # Setting up request parameters and headers
    headers = {'x-api-key': lightbox_api_key}

    # Sending request to the LightBox API
    response = requests.get(URL, headers=headers)
    return response

# %% [markdown]
# ### 3. Create variable(s) that will be used to authenticate your calls.
# Get your key from the [LightBox Developer Portal](https://developer.lightboxre.com/).

# %%
# Set your API key
lightbox_api_key = '<YOUR_API_KEY>>'

# %% [markdown]
# ### 4. Fetching Data
# Pass in the LightBoxID and/or Country Code to each function and print the response.

# %%
# Get parcel data
parcel_data = get_parcel(lightbox_api_key, 'US', '0201MABNPDBU5D2EGP08YA')
print("Parcel Data:", json.dumps(parcel_data.json(), indent=4))

# Get demographics data
demographics_data = get_demographics(lightbox_api_key, '0201MABNPDBU5D2EGP08YA')
print("Demographics Data:", json.dumps(demographics_data.json(), indent=4))

# Get Wetlands data
wetlands_data = get_wetlands(lightbox_api_key, '0200SD3985NHUDEC0TL67G')
print("Wetlands Data:", json.dumps(wetlands_data.json(), indent=4))

# Get NFHL data
nfhls_data = get_nfhls(lightbox_api_key, '0200HK4FSP4RPX8VVBQ1N0')
print("NFHL Data:", json.dumps(nfhls_data.json(), indent=4))

# Get Risk Indexes
risk_indexes_data = get_risk_indexes(lightbox_api_key, '0200HK4FSP4RPX8VVBQ1N0')
print("Risk Indexes Data:", json.dumps(risk_indexes_data.json(), indent=4))

# Get Zoning data
zoning_data = get_zoning(lightbox_api_key, 'US', '0200EYAN6C9OGWBUD0IIIO')
print("Zoning Data:", json.dumps(zoning_data.json(), indent=4))
# Out:
# Parcel Data: {
#     "$ref": "https://api.lightboxre.com/v1/parcels/US/0201MABNPDBU5D2EGP08YA",
#     "$metadata": {
#         "geogcs": {
#             "epsg": "4269"
#         },
#         "currency": {
#             "code": "usd"
#         },
#         "units": {
#             "length": "m",
#             "area": "sqm"
#         },
#         "recordSet": {
#             "totalRecords": 1.0,
#             "offset": null,
#             "limit": null,
#             "bbox": {
#                 "xMax": -89.3182,
#                 "xMin": -89.318714,
#                 "yMax": 34.915042,
#                 "yMin": 34.914674
#             }
#         }
#     },
#     "parcels": [
#         {
#             "$ref": "https://api.lightboxre.com/v1/parcels/us/0201MABNPDBU5D2EGP08YA",
#             "id": "0201MABNPDBU5D2EGP08YA",
#             "$metadata": {
#                 "geocode": null
#             },
#             "fips": "28009",
#             "parcelApn": "2-0091-17-000-006.01",
#             "assessment": {
#                 "alternateApn": "24477",
#                 "apn": "2-0091-17-000-006.01",
#                 "assessedValue": {
#                     "total": 1804.0,
#                     "land": null,
#                     "improvements": null,
#                     "year": "2023"
#                 },
#                 "marketValue": {
#                     "total": 12020.0,
#                     "land": 350.0,
#                     "improvements": 11670.0,
#                     "year": "2023"
#                 },
#                 "improvementPercent": null,
#                 "lot": {
#                     "lotNumber": "19",
#                     "blockNumber": null,
#                     "depth": null,
#                     "width": null,
#                     "size": 931.1338289962825
#                 },
#                 "poolIndicator": null,
#                 "zoning": {
#                     "assessment": null
#                 },
#                 "book": null,
#                 "page": null
#             },
#             "cbsa": {
#                 "code": null
#             },
#             "census": {
#                 "blockGroup": "1",
#                 "tract": "950101"
#             },
#             "county": "BENTON",
#             "derived": {
#                 "calculatedLotArea": 981.3197026022304
#             },
#             "landUse": {
#                 "code": null,
#                 "description": "MISCELLANEOUS (GENERAL)",
#                 "normalized": {
#                     "code": "0010",
#                     "description": "MISCELLANEOUS (GENERAL)",
#                     "categoryDescription": "MISCELLANEOUS"
#                 }
#             },
#             "lastLoan": {
#                 "recordingDate": null,
#                 "dueDate": "2013-02-12T00:00:00.000Z",
#                 "lender": null,
#                 "value": null,
#                 "transactionId": "",
#                 "interestRates": []
#             },
#             "legalDescription": [
#                 "NW PART OF LOT 19"
#             ],
#             "location": {
#                 "streetAddress": "30 LEAK DR",
#                 "countryCode": "US",
#                 "locality": "LAMAR",
#                 "regionCode": "MS",
#                 "postalCode": "38642",
#                 "postalCodeExt": null,
#                 "geometry": {
#                     "wkt": "POLYGON ((-89.3183290444553 34.9146735391809, -89.3181997701329 34.9148658252548, -89.3185849366835 34.9150415245806, -89.3187142103731 34.9148492381077, -89.3183290444553 34.9146735391809))"
#                 },
#                 "representativePoint": {
#                     "longitude": -89.318457,
#                     "latitude": 34.914858,
#                     "geometry": {
#                         "wkt": "POINT (-89.318457 34.914858)"
#                     }
#                 }
#             },
#             "neighborhood": null,
#             "occupant": {
#                 "owner": false,
#                 "company": false
#             },
#             "owner": {
#                 "names": [
#                     {
#                         "fullName": "ALLEN, JOEL",
#                         "firstName": "JOEL",
#                         "middleName": null,
#                         "lastName": "ALLEN"
#                     },
#                     {
#                         "fullName": "ALLEN, WILMA",
#                         "firstName": "WILMA",
#                         "middleName": null,
#                         "lastName": "ALLEN"
#                     }
#                 ],
#                 "streetAddress": null,
#                 "countryCode": "US",
#                 "locality": "LAMAR",
#                 "regionCode": "MS",
#                 "postalCode": "38642",
#                 "postalCodeExt": null,
#                 "ownerNameStd": null,
#                 "ownershipStatus": {
#                     "code": "HW",
#                     "description": "HUSBAND AND WIFE"
#                 }
#             },
#             "opportunityZone": false,
#             "primaryStructure": {
#                 "yearBuilt": null,
#                 "yearRenovated": null
#             },
#             "related": {
#                 "commonOwnership": {
#                     "aggregateLotSize": 0.0,
#                     "id": "511448401_58",
#                     "count": 1.0,
#                     "subdivision": null,
#                     "lotWidthMedian": null,
#                     "lotWidthSummary": null
#                 },
#                 "associatePropertyCount": 1.0
#             },
#             "subdivision": null,
#             "structures": [
#                 {
#                     "$ref": "https://api.lightboxre.com/v1/structures/0501C58EX3CFSULTYW1HR0",
#                     "id": "0501C58EX3CFSULTYW1HR0"
#                 }
#             ],
#             "tax": {
#                 "year": null,
#                 "yearDelinquent": null,
#                 "amount": null,
#                 "taxRateAreaCode": null,
#                 "id": "US_28_009_2-0091-17-000-006.01",
#                 "taxAccountNumber": "24477",
#                 "exemption": "SENIOR CITIZEN"
#             },
#             "topography": "",
#             "transaction": {
#                 "lastMarketSale": {
#                     "pricePerArea": null,
#                     "value": null,
#                     "seller": "",
#                     "buyer": "ALLEN JOEL AND WILMA",
#                     "filingDate": "2013-02-12T00:00:00.000Z",
#                     "transferDate": "2013-02-12T00:00:00.000Z",
#                     "documentNumber": "",
#                     "documentTypeCode": "",
#                     "documentTypeDescription": "",
#                     "lender": "",
#                     "loan": {
#                     "person2": 224.0,
#                     "person3": 35.0,
#                     "person4": 204.0,
#                     "person5": 0.0,
#                     "person6": 21.0,
#                     "person7Plus": 0.0
#                 },
#                 "income": {
#                     "totalPersonal": 44705950.0,
#                     "total": 44705950.0,
#                     "median": 69492.0,
#                     "average": 65841.0,
#                     "perCapita": 24284.0,
#                     "averageHigh": 0.0,
#                     "upTo14999": 38.0,
#                     "i15000To24999": 80.0,
#                     "i25000To34999": 51.0,
#                     "i35000To44999": 79.0,
#                     "i50000To74999": 117.0,
#                     "i75000To99999": 184.0,
#                     "i100000To124999": 108.0,
#                     "i125000To199999": 22.0,
#                     "i500000To199999": 0.0,
#                     "i200000Plus": 0.0
#                 }
#             },
#             "housing": {
#                 "medianValue": 71892.0,
#                 "medianBuilt": "1989",
#                 "housingUnits": {
#                     "count": 794.0,
#                     "occupied": 679.0,
#                     "vacant": 115.0,
#                     "vacantForRent": 0.0,
#                     "ownerOccupied": 522.0,
#                     "renterOccupied": 157.0,
#                     "ownerOccupiedPercentage": 0.657430730478589,
#                     "renterOccupiedPercentage": 0.197732997481108,
#                     "vacantPercentage": 0.144836272040302
#                 }
#             },
#             "population": {
#                 "density": 24.0,
#                 "y1990": null,
#                 "y2000": 1778.0,
#                 "y2010": 1910.0,
#                 "y2020": 1804.0,
#                 "current": 1841.0,
#                 "projectedY2023": 1839.0,
#                 "forecast": -0.0,
#                 "urban": 0.0,
#                 "rural": 1841.0,
#                 "male": 1021.0,
#                 "female": 820.0,
#                 "whiteAlone": 508.0,
#                 "blackAlone": 1193.0,
#                 "asianAlone": 1.0,
#                 "indigenousAlone": 8.0,
#                 "otherRacesAlone": 62.0,
#                 "multipleRaces": 69.0,
#                 "hispanic": 83.0,
#                 "whiteNonHispanic": 503.0,
#                 "age": {
#                     "median": 41.1,
#                     "medianFemale": 46.5,
#                     "medianMale": 39.5,
#                     "a0To5": 73.0,
#                     "a6To11": 121.0,
#                     "a12To17": 194.0,
#                     "a18To24": 137.0,
#                     "a25To34": 80.0,
#                     "a35To44": 521.0,
#                     "a45To54": 126.0,
#                     "a55To64": 268.0,
#                     "a65To74": 156.0,
#                     "a75To84": 155.0,
#                     "a85Plus": 10.0
#                 }
#             },
#             "education": {
#                 "total": {
#                     "higher": 4.0,
#                     "elementary": 260.0,
#                     "middle": 0.0,
#                     "high": 145.0,
#                     "college": 140.0,
#                     "collegePercentage": 0.106382978723404
#                 },
#                 "attainment": {
#                     "lessThanHighschool": 353.0,
#                     "highSchool": 376.0,
#                     "someCollege": 328.0,
#                     "associates": 119.0,
#                     "bachelor": 51.0,
#                     "master": 89.0,
#                     "professionalDegree": 0.0,
#                     "doctorate": 0.0
#                 }
#             },
#             "crime": {
#                 "murders": 116.0,
#                 "rape": 128.0,
#                 "robbery": 103.0,
#                 "assault": 84.0,
#                 "burglary": 123.0,
#                 "larceny": 50.0,
#                 "carTheft": 71.0,
#                 "total": 86.0
#             },
#             "totalAnnualExpenditures": 38218.0,
#             "work": {
#                 "employees": 49.0,
#                 "establishments": 8.0,
#                 "averageTravelTime": 31.0
#             },
#             "sales": {
#                 "buildingAndGarden": 0.0,
#                 "building": 422356000.0,
#                 "agriculture": 845184.19
#             },
#             "score": 18.45,
#             "countyScore": 18.65,
#             "stateAverageScore": 25.51,
#             "nationalAverageScore": 16.91,
#             "rating": "Relatively Moderate",
#             "countyRating": "Relatively Moderate",
#             "nationalPercentile": 64.81,
#             "statePercentile": 17.98,
#             "expectedAnnualLoss": {
#                 "score": 20.74,
#                 "stateAverageScore": 27.59,
#                 "nationalAverageScore": 18.03,
#                 "rating": "Relatively Moderate",
#                 "nationalPercentile": 69.61,
#                 "statePercentile": 21.65,
#                 "total": 448912.56,
#                 "countyTotal": 50904838.54,
#                 "value": {
#                     "building": 255668.08,
#                     "agriculture": 122.55
#                 },
#                 "population": 0.03,
#                 "populationEquivalence": 193121.93
#             },
#             "socialVulnerability": {
#                 "score": 29.84,
#                 "countyScore": 27.51,
#                 "stateAverageScore": 31.13,
#                 "nationalAverageScore": 31.89,
#                 "rating": "Relatively Low",
#                 "countyRating": "Relatively Low",
#                 "nationalPercentile": 29.55,
#                 "statePercentile": 39.44,
#                 "value": -1.28,
#                 "countyValue": -2.75
#             },
#             "communityResilience": {
#                 "score": 53.96,
#                 "countyScore": 53.96,
#                 "stateAverageScore": 53.84,
#                 "nationalAverageScore": 54.91,
#                 "rating": "Relatively Moderate",
#                 "countyRating": "Relatively Moderate",
#                 "nationalPercentile": 41.65,
#                 "statePercentile": 71.79,
#                 "value": 2.7,
#                 "cuntyValue": 2.7
#             },
#             "avalanche": {
#                 "events": 2.0,
#                 "annualizedFrequency": 0.03,
#                 "exposure": 39000000.0,
#                 "annualLoss": {
#                     "total": 80787.11,
#                     "score": 26.79,
#                     "rating": "Relatively Low",
#                     "historicLossRatioTotalRating": "Relatively Moderate"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 15.38,
#                     "rating": "Relatively Low"
#                 }
#             },
#             "coastalFlooding": {
#                 "events": null,
#                 "annualizedFrequency": 4.5,
#                 "exposure": 28395081.59,
#                 "annualLoss": {
#                     "total": 4.08,
#                     "score": 0.53,
#                     "rating": "Very Low",
#                     "historicLossRatioTotalRating": "Very Low"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 0.47,
#                     "rating": "Very Low"
#                 }
#             },
#             "coldWave": {
#                 "events": 0.0,
#                 "annualizedFrequency": 0.0,
#                 "exposure": 0.0,
#                 "annualLoss": {
#                     "total": 0.0,
#                     "score": 0.0,
#                     "rating": "No Expected Annual Losses",
#                     "historicLossRatioTotalRating": "No Rating"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 0.0,
#                     "rating": "No Rating"
#                 }
#             },
#             "drought": {
#                 "events": 0.0,
#                 "annualizedFrequency": 0.0,
#                 "exposure": 0.0,
#                 "annualLoss": {
#                     "total": 0.0,
#                     "score": 0.0,
#                     "rating": "No Expected Annual Losses",
#                     "historicLossRatioTotalRating": "No Rating"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 0.0,
#                     "rating": "No Rating"
#                 }
#             },
#             "earthquake": {
#                 "events": null,
#                 "annualizedFrequency": 0.0,
#                 "exposure": 35990356000.0,
#                 "annualLoss": {
#                     "total": 214330.22,
#                     "score": 24.78,
#                     "rating": "Relatively High",
#                     "historicLossRatioTotalRating": "Very Low"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 24.86,
#                     "rating": "Relatively Moderate"
#                 }
#             },
#             "hail": {
#                 "events": 3.0,
#                 "annualizedFrequency": 0.09,
#                 "exposure": 35991201184.2,
#                 "annualLoss": {
#                     "total": 146.24,
#                     "score": 3.39,
#                     "rating": "Very Low",
#                     "historicLossRatioTotalRating": "Very Low"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 3.21,
#                     "rating": "Very Low"
#                 }
#             },
#             "heatWave": {
#                 "events": 30.0,
#                 "annualizedFrequency": 2.47,
#                 "exposure": 35991198831.6,
#                 "annualLoss": {
#                     "total": 1274.04,
#                     "score": 11.68,
#                     "rating": "Relatively Low",
#                     "historicLossRatioTotalRating": "Very Low"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 9.95,
#                     "rating": "Relatively Low"
#                 }
#             },
#             "hurricane": {
#                 "events": null,
#                 "annualizedFrequency": null,
#                 "exposure": null,
#                 "annualLoss": {
#                     "total": null,
#                     "score": null,
#                     "rating": "Not Applicable",
#                     "historicLossRatioTotalRating": "Not Applicable"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": null,
#                     "rating": "Not Applicable"
#                 }
#             },
#             "iceStorm": {
#                 "events": 110.0,
#                 "annualizedFrequency": 1.63,
#                 "exposure": 35987441091.9,
#                 "annualLoss": {
#                     "total": 3429.07,
#                     "score": 20.56,
#                     "rating": "Relatively Low",
#                     "historicLossRatioTotalRating": "Very Low"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 15.1,
#                     "rating": "Relatively Low"
#                 }
#             },
#             "landslide": {
#                 "events": 0.0,
#                 "annualizedFrequency": 0.01,
#                 "exposure": 22700203884.5,
#                 "annualLoss": {
#                     "total": 351.92,
#                     "score": 3.43,
#                     "rating": "Relatively Low",
#                     "historicLossRatioTotalRating": "Very Low"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 2.65,
#                     "rating": "Relatively Low"
#                 }
#             },
#             "lightning": {
#                 "events": 26.0,
#                 "annualizedFrequency": 1.17,
#                 "exposure": 35990356000.0,
#                 "annualLoss": {
#                     "total": 1252.28,
#                     "score": 17.59,
#                     "rating": "Relatively Low",
#                     "historicLossRatioTotalRating": "Relatively Moderate"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 12.52,
#                     "rating": "Very Low"
#                 }
#             },
#             "riverineFlooding": {
#                 "events": 10.0,
#                 "annualizedFrequency": 0.42,
#                 "exposure": 341393150.22,
#                 "annualLoss": {
#                     "total": 1164.7,
#                     "score": 4.75,
#                     "rating": "Very Low",
#                     "historicLossRatioTotalRating": "Very Low"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 3.97,
#                     "rating": "Very Low"
#                 }
#             },
#             "strongWind": {
#                 "events": 2.0,
#                 "annualizedFrequency": 0.06,
#                 "exposure": 35991201184.2,
#                 "annualLoss": {
#                     "total": 163.67,
#                     "score": 5.28,
#                     "rating": "Very Low",
#                     "historicLossRatioTotalRating": "Very Low"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 5.37,
#                     "rating": "Very Low"
#                 }
#             },
#             "tornado": {
#                 "events": 0.0,
#                 "annualizedFrequency": 0.0,
#                 "exposure": 35991201184.2,
#                 "annualLoss": {
#                     "total": 5956.6,
#                     "score": 12.91,
#                     "rating": "Very Low",
#                     "historicLossRatioTotalRating": "Very Low"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 13.61,
#                     "rating": "Very Low"
#                 }
#             },
#             "tsunami": {
#                 "events": 0.0,
#                 "annualizedFrequency": 0.0,
#                 "exposure": 0.0,
#                 "annualLoss": {
#                     "total": 0.0,
#                     "score": 0.0,
#                     "rating": "No Expected Annual Losses",
#                     "historicLossRatioTotalRating": "No Rating"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 0.0,
#                     "rating": "No Rating"
#                 }
#             },
#             "volcanicActivity": {
#                 "events": 2.0,
#                 "annualizedFrequency": 0.0,
#                 "exposure": 35990353647.5,
#                 "annualLoss": {
#                     "total": 139513.49,
#                     "score": 59.91,
#                     "rating": "Very High",
#                     "historicLossRatioTotalRating": "Very Low"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 53.23,
#                     "rating": "Relatively High"
#                 }
#             },
#             "wildfire": {
#                 "events": null,
#                 "annualizedFrequency": 0.0,
#                 "exposure": 77131212.62,
#                 "annualLoss": {
#                     "total": 9.42,
#                     "score": 0.86,
#                     "rating": "Very Low",
#                     "historicLossRatioTotalRating": "Very Low"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 0.75,
#                     "rating": "Very Low"
#                 }
#             },
#             "winterWeather": {
#                 "events": 24.0,
#                 "annualizedFrequency": 1.98,
#                 "exposure": 35991198831.6,
#                 "annualLoss": {
#                     "total": 529.72,
#                     "score": 12.88,
#                     "rating": "Relatively Low",
#                     "historicLossRatioTotalRating": "Very Low"
#                 },
#                 "hazardTypeRiskIndex": {
#                     "score": 6.97,
#                     "rating": "Relatively Low"
#                 }
#             }
#         }
#     ]
# }
# Zoning Data: {
#     "$ref": "https://api.lightboxre.com/v1/zoning/_on/parcel/US/0200EYAN6C9OGWBUD0IIIO",
#     "$metadata": {
#         "geogcs": {
#             "epsg": "4269"
#         },
#         "currency": {
#             "code": "usd"
#         },
#         "units": {
#             "length": "ft",
#             "area": "sqft"
#         },
#         "recordSet": {
#             "totalRecords": 1.0
#         }
#     },
#     "zonings": [
#         {
#             "$ref": "https://api.lightboxre.com/v1/zoning/_on/parcel/us/0200EYAN6C9OGWBUD0IIIO",
#             "$metadata": {
#                 "intersect": 1.0,
#                 "vintage": {
#                     "ordinance": "2019-06-18T00:00:00.000Z",
#                     "zoning": null
#                 },
#                 "ordinanceUrl": "https://assets.bouldercounty.org/wp-content/uploads/2017/02/land-use-code-article-04.pdf"
#             },
#             "parcel": {
#                 "$ref": "https://api.lightboxre.com/v1/parcels/us/0200EYAN6C9OGWBUD0IIIO",
#                 "fips": "08013",
#                 "id": "0200EYAN6C9OGWBUD0IIIO"
#             },
#             "jurisdiction": {
#                 "id": "08013",
#                 "type": "COUNTY",
#                 "name": "BOULDER"
#             },
#             "type": "ALL",
#             "category": "OTHER",
#             "code": {
#                 "value": "F",
#                 "valueUnformatted": "f",
#                 "label": "CODE"
#             },
#             "district": {
#                 "value": "FORESTRY",
#                 "label": "DISTRICT"
#             },
#             "description": {
#                 "value": "Forestry District",
#                 "label": "DESCRIPTION"
#             },
#             "summary": {
#                 "value": "Rural areas established for the purpose of efficiently using land to conserve forest resources, protect the natural environment, and preserve open areas.",
#                 "label": "PURPOSE"
#             },
#             "densityFloorArea": {
#                 "value": null,
#                 "description": null,
#                 "label": "MAXIMUM FLOOR AREA RATIO"
#             },
#             "maximumSiteCoverage": {
#                 "percent": null,
#                 "description": null,
#                 "label": "MAXIMUM LOT COVERAGE"
#             },
#             "minimumLotArea": {
#                 "perUnit": null,
#                 "perLot": 1524600.0,
#                 "description": "Subdivided with Water and Sewer in a Community Service Area: 1524600 sq ft; Unsubdivided: 1524600 sq ft.",
#                 "label": "MINIMUM LOT SIZE"
#             },
#             "frontSetback": {
#                 "distance": 15.0,
#                 "description": "15 ft",
#                 "label": "FRONT SETBACK"
#             },
#             "sideSetback": {
#                 "distance": 25.0,
#                 "description": "25 ft",
#                 "label": "SIDE SETBACK"
#             },
#             "rearSetback": {
#                 "distance": 15.0,
#                 "description": "15 ft",
#                 "label": "REAR SETBACK"
#             },
#             "maximumBuildingHeight": {
#                 "height": 30.0,
#                 "maxStories": null,
#                 "timesBuildableArea": null,
#                 "description": "30 ft",
#                 "label": "HEIGHT"
#             }
#         }
#     ]
# }
